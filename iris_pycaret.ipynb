# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadghazyy/pycaret/blob/main/iris_pycaret.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret

# %%
import pandas as pd
import pycaret.classification
import sklearn

# %%
iris = sklearn.datasets.load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['target']=iris.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
iriscaret = pycaret.classification.setup(df ,target='target')
# Out:
#                                Description             Value
# 0                               session_id              2329
# 1                                   Target            target
# 2                              Target Type        Multiclass
# 3                            Label Encoded  0: 0, 1: 1, 2: 2
# 4                            Original Data          (150, 5)
# 5                           Missing Values             False
# 6                         Numeric Features                 4
# 7                     Categorical Features                 0
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set          (104, 4)
# 12                    Transformed Test Set           (46, 4)
# 13                      Shuffle Train-Test              True
# ...

# %%
iris_model = pycaret.classification.compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# knn                K Neighbors Classifier    0.9909  1.0000  0.9917  0.9932
# lr                    Logistic Regression    0.9800  0.9969  0.9833  0.9850
# nb                            Naive Bayes    0.9800  0.9969  0.9806  0.9845
# lda          Linear Discriminant Analysis    0.9800  1.0000  0.9806  0.9845
# rf               Random Forest Classifier    0.9709  0.9985  0.9722  0.9777
# qda       Quadratic Discriminant Analysis    0.9709  1.0000  0.9722  0.9777
# gbc          Gradient Boosting Classifier    0.9709  0.9858  0.9722  0.9777
# et                 Extra Trees Classifier    0.9709  1.0000  0.9722  0.9777
# lightgbm  Light Gradient Boosting Machine    0.9618  1.0000  0.9611  0.9704
# dt               Decision Tree Classifier    0.9609  0.9711  0.9639  0.9702
# ada                  Ada Boost Classifier    0.9518  0.9960  0.9528  0.9629
# ...

# %%
final = pycaret.classification.predict_model(iris_model,df)

# %%
false = final[['target','Label']].loc[final['target']!=final['Label']].count()
true = final[['target','Label']].loc[final['target']==final['Label']].count()
accuracy = (true)/(false+true)
print(f"The accuracy for the model is {accuracy}")
# Out:
# The accuracy for the model is target    0.973333
# Label     0.973333
# dtype: float64
