# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadghazyy/pycaret/blob/main/heart_disease_pycaret.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Errands

# %%
# !pip install pycaret

# %%
import pandas as pd
import pycaret.classification

from google.colab import files

# %%
files.upload()
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d ronitf/heart-disease-uci
# !unzip heart-disease-uci.zip
# Out:
#      <input type="file" id="files-9036c496-74c9-4597-a6c0-c81f3bdcd24f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9036c496-74c9-4597-a6c0-c81f3bdcd24f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# ...
#   0% 0.00/3.40k [00:00<?, ?B/s]
# 100% 3.40k/3.40k [00:00<00:00, 6.55MB/s]

# %%
heart = pd.read_csv('heart.csv')
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %% [markdown]
# ## Making the model

# %%
cat_var = ['sex','cp','fbs','restecg','exang','thal']
initial = pycaret.classification.setup(heart , target='target',categorical_features=cat_var)
# Out:
#                                Description             Value
# 0                               session_id              8541
# 1                                   Target            target
# 2                              Target Type            Binary
# 3                            Label Encoded        0: 0, 1: 1
# 4                            Original Data         (303, 14)
# 5                           Missing Values             False
# 6                         Numeric Features                 5
# 7                     Categorical Features                 8
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set         (212, 27)
# 12                    Transformed Test Set          (91, 27)
# 13                      Shuffle Train-Test              True
# ...

# %%
modelkita = pycaret.classification.compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# ridge                    Ridge Classifier    0.8396  0.0000  0.8859  0.8492
# lda          Linear Discriminant Analysis    0.8396  0.9173  0.8942  0.8456
# lr                    Logistic Regression    0.8394  0.9128  0.8692  0.8630
# nb                            Naive Bayes    0.8206  0.8728  0.8199  0.8663
# gbc          Gradient Boosting Classifier    0.8206  0.8964  0.8776  0.8300
# lightgbm  Light Gradient Boosting Machine    0.8160  0.8910  0.8776  0.8280
# rf               Random Forest Classifier    0.8067  0.8921  0.8449  0.8335
# ada                  Ada Boost Classifier    0.7879  0.8360  0.8609  0.7927
# et                 Extra Trees Classifier    0.7831  0.8821  0.8532  0.7941
# dt               Decision Tree Classifier    0.7268  0.7158  0.7872  0.7584
# qda       Quadratic Discriminant Analysis    0.6468  0.6365  0.7064  0.7069
# ...

# %%
final = pycaret.classification.predict_model(modelkita,heart)

# %%
submission = pd.DataFrame({"age":final['age'],"label":final['Label']})
submission
# Out:
#      age  label
# 0     63      1
# 1     37      1
# 2     41      1
# 3     56      1
# 4     57      1
# ..   ...    ...
# 298   57      0
# 299   45      1
# 300   68      0
# 301   57      0
# 302   57      1
#
# [303 rows x 2 columns]
